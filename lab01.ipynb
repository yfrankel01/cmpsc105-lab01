# %% [markdown]
# This is your Lab 01 notebook. You will be using notebooks like this one to complete lab exercises. Please follow the instructions carefully and make sure to save your work frequently.

# %%
# import libraries in this cell
# you only need pandas today

import pandas as pd

# Load the dataset
# We refer to the file by its exact name: "dining.csv"
df = pd.read_csv("dining.csv")

# Display the first 5 rows to understand the structure
print(df.head())
# Out:
#          date dining_hall  swipes featured_item  week  coffee_consumed
# 0  2024-01-08      Brooks     108         Pasta     1               24
# 1  2024-01-08    McKinley     126        Burger     1               22
# 2  2024-01-09      Brooks     112       Chicken     1               26
# 3  2024-01-09    McKinley     129         Pizza     1               24
# 4  2024-01-10      Brooks     116         Tacos     1               27

# %%
# read in your data in this cell
df.shape
# Out:
# (30, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             30 non-null     str
#  1   dining_hall      30 non-null     str
#  2   swipes           30 non-null     int64
#  3   featured_item    30 non-null     str
#  4   week             30 non-null     int64
#  5   coffee_consumed  30 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 1.5 KB

# %%
brooks_df = df[df["dining_hall"] == "Brooks"]
print(brooks_df.head(5))
# Out:
#          date dining_hall  swipes featured_item  week  coffee_consumed
# 0  2024-01-08      Brooks     108         Pasta     1               24
# 2  2024-01-09      Brooks     112       Chicken     1               26
# 4  2024-01-10      Brooks     116         Tacos     1               27
# 6  2024-01-11      Brooks     110      Stir-Fry     1               29
# 8  2024-01-12      Brooks     119       Burrito     1               31

# %%
df["average_coffee"] = (df["coffee_consumed"])/(df["swipes"])
print(df["average_coffee"].head(5))
# Out:
# 0    0.222222
# 1    0.174603
# 2    0.232143
# 3    0.186047
# 4    0.232759
# Name: average_coffee, dtype: float64

# %%
df = df.sort_values(by="average_coffee", ascending=False)

print(df.head(5))
# Out:
#           date dining_hall  swipes featured_item  week  coffee_consumed  \
# 28  2024-01-26      Brooks     130       Lasagna     3               40
# 26  2024-01-25      Brooks     134        Burger     3               38
# 24  2024-01-24      Brooks     128         Tacos     3               36
# 22  2024-01-23      Brooks     121         Pasta     3               34
# 16  2024-01-18      Brooks     118      Stir-Fry     2               33
#
#     cafeine_free  average_coffee
# 28            90        0.307692
# 26            96        0.283582
# 24            92        0.281250
# 22            87        0.280992
# 16            85        0.279661

# %%
# Save the modified DataFrame to a new file
# index=False prevents pandas from writing row numbers as a new column
df.to_csv("modified_dining.csv", index=False)
